# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/YashikaChandra06/flyrank-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
my_lane = """
My Lane: Freestyle – How do AI-generated website pages compare with human-written pages
in terms of content quality, SEO, readability, and user experience?

I chose this question because AI-generated content is becoming increasingly common in
modern web development and digital marketing. I want to analyze whether AI can
consistently produce high-quality web pages that are informative, optimized for search
engines, and easy for users to read. This study will help identify the strengths and
limitations of AI-generated content and provide practical insights for businesses that
rely on AI for content creation.
"""

print(my_lane)
# Out:
# My Lane: Freestyle – How do AI-generated website pages compare with human-written pages
# in terms of content quality, SEO, readability, and user experience?
#
# I chose this question because AI-generated content is becoming increasingly common in
# modern web development and digital marketing. I want to analyze whether AI can
# consistently produce high-quality web pages that are informative, optimized for search
# engines, and easy for users to read. This study will help identify the strengths and
# limitations of AI-generated content and provide practical insights for businesses that
# rely on AI for content creation.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
decision = """
The Question: Decision, Action, and Cost of a Wrong Call

Decision:
My analysis helps businesses decide whether to use AI-generated website content,
human-written content, or a combination of both for their websites.

Who acts on it?
Content managers, SEO specialists, digital marketing teams, and business owners
can use the findings to choose the most effective content strategy.

Cost of a wrong recommendation:
A poor recommendation can lead to lower search engine rankings, reduced website
traffic, poor user engagement, loss of customer trust, and decreased sales or
conversions. It may also increase the time and cost required to rewrite or
optimize website content.
"""

print(decision)
# Out:
# The Question: Decision, Action, and Cost of a Wrong Call
#
# Decision:
# My analysis helps businesses decide whether to use AI-generated website content,
# human-written content, or a combination of both for their websites.
#
# Who acts on it?
# Content managers, SEO specialists, digital marketing teams, and business owners
# can use the findings to choose the most effective content strategy.
#
# Cost of a wrong recommendation:
# A poor recommendation can lead to lower search engine rankings, reduced website
# traffic, poor user engagement, loss of customer trust, and decreased sales or
# conversions. It may also increase the time and cost required to rewrite or
# optimize website content.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

# Load the starter dataset
  # Replace with the correct file name if needed

print("Dataset Shape:", df.shape)
print("Number of Columns:", len(df.columns))
print("Missing Values:", df.isnull().sum().sum())

# Display the first few rows
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 6
#       2 # Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
#       3 import pandas as pd
#       4
#       5 # Load the starter dataset
# ----> 6 df = pd.read_csv("anonymized.csv")   # Replace with the correct file name if needed
#       7
#       8 print("Dataset Shape:", df.shape)
#       9 print("Number of Columns:", len(df.columns))
#
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
careful_words = """
What My Work Can and Can't Claim

What this work can say:
- It can identify patterns and differences between AI-generated and human-written website content.
- It can provide evidence-based recommendations to support decisions about content creation.
- It can highlight which content characteristics are associated with better readability, SEO, and user engagement.

What this work cannot say:
- It cannot prove that AI-generated or human-written content directly causes better search rankings or higher traffic.
- It cannot predict Google's search algorithm or future ranking changes.
- It cannot guarantee that the findings will apply to every website, industry, or audience.
"""

print(careful_words)

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
